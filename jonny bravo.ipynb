# %%
from turtle import *

# %%
s=Screen()
s.screensize(700,1000)
speed(1000)
def myPosition(x, y):
    penup()
    goto(x, y)
    pendown()
pensize(2)
def ankur():
    fillcolor('#3399ff')
    begin_fill()
    left(15)
    forward(30)
    backward(10)
    right(90)
    forward(100)
    left(70)
    forward(20)
    left(95)
    forward(130)
    left(100)
    forward(40)
    right(15)
    forward(40)
    right(60)
    forward(10)
    left(100)
    circle(100,30)
    left(30)
    forward(95)
    left(95)
    forward(20)
    left(65)
    forward(90)
    
    
    end_fill()

# %%
def legbleow():
    myPosition(-55,-95)
    fillcolor('#3399ff')
    begin_fill()
    
    right(64)
    forward(43)
    right(100)
    forward(12)
    right(87)
    forward(40)
    right(85)
    forward(8)

    end_fill()

# %%
def legbleowr():
    myPosition(35,-90)
    fillcolor('#3399ff')
    begin_fill()
    right(105)
    forward(40)
    right(80)
    forward(7)
    right(90)
    forward(40)
    right(90)
    forward(15)
    end_fill()

# %%
def shoesr():
    myPosition(45,-105)
    fillcolor('#000000')
    begin_fill()
    right(180)
    forward(15)
    left(90)
    forward(15)
    left(60)
    forward(5)
    right(120)
    forward(5)
    left(60)
    forward(50)
    left(80)
    circle(20,170)
    right(120)
    forward(10)
    end_fill()

# %%
def shoels():
    myPosition(-25,-100)
    fillcolor('#000000')
    begin_fill()
    right(230)
    forward(20)
    right(80)
    forward(15)
    right(120)
    forward(7)
    left(140)
    forward(15)
    right(30)
    forward(40)
    right(250)
    circle(20,-170)
    right(45)
    forward(2)
    end_fill()

# %%
def shirt():
   myPosition(-20,40) 
   fillcolor('#000000')
   begin_fill()
   left(30)
   circle(300,35)
   left(90)
   forward(30)
   left(90)
   forward(10)
   right(90)
   forward(10)
   right(90)
   forward(10)
   circle(300,10)
   right(60)
   forward(20)
   right(120)
   forward(15)
   left(90)
   forward(50)
   right(240)
   circle(100,-25)
   right(-80)
   circle(70,-45)
   left(70)
   forward(30)
   right(-85)
   circle(100,50)
   left(80)
   forward(24)
   right(-70)
   circle(100,-25)
   right(120)
   forward(50)
   right(60)
   forward(30)
   left(90)
   forward(5)
   right(60)
   forward(30)
   right(-80)
   circle(200,-17)
   right(-100)
   forward(7)
   right(80)
   forward(5)
   left(100)
   forward(15)
   left(120)
   forward(30)
   right(66)
   forward(193)
   right(55)
   forward(40)
   right(10)
   forward(40)

   end_fill()

# %%
def handl():
    myPosition(-120,170)
    fillcolor('#ffcc99')
    begin_fill()
    right(120)
    circle(100,-20)
    myPosition(-130,160)
    right(80)
    forward(144)
    right(90)
    forward(40)
    right(90)
    forward(20)
    right(80)
    forward(7)
    right(45)
    forward(10)
    backward(10)
    left(90)
    forward(15)
    right(90)
    forward(3)
    backward(3)
    left(145)
    forward(170)
    right(103)
    forward(100)
    end_fill()

# %%
def handr():
    myPosition(162,229)
    fillcolor('#ffcc99')
    begin_fill()
    right(50)
    forward(120)
    right(-90)
    circle(200,40)
    right(-20)
    forward(30)
    left(40)
    forward(30)
    left(70)
    forward(20)
    left(90)
    forward(20)
    left(120)
    forward(15)
    backward(15)
    right(140)
    forward(15)
    left(-70)
    circle(100,40)
    myPosition(212,280)
    left(-125)
    forward(36)
    end_fill()

# %%
def neck():
    myPosition(-37,270)
    fillcolor('#ffcc99')
    begin_fill()
    right(100)
    forward(25)
    right(160)
    forward(20)
    left(85)
    forward(45)
    left(80)
    forward(15)
    right(145)
    forward(50)
    right(270)
    circle(100,-50)
    right(-100)
    forward(30)
    end_fill()

# %%
def face():
    myPosition(-31,290)
    fillcolor('#ffcc99')
    begin_fill()
    left(18)
    forward(60)
    right(90)
    forward(60)
    right(100)
    forward(80)
    right(85)
    forward(45)
    end_fill()

# %%
def earsl():
    myPosition(-32,310)
    fillcolor('#ffcc99')
    begin_fill()
    right(170)
    circle(8,-180)
    end_fill()
    # forward(100)

# %%
def earsr():
    myPosition(21,326)
    fillcolor('#ffcc99')
    begin_fill()
    right(15)
    circle(8,-180)
    end_fill()

# %%
def glass():
    myPosition(21,326)
    fillcolor('#000000')
    begin_fill()
    right(180)
    forward(10)
    circle(10)
    right(5)
    forward(18)
    left(100)
    forward(20)
    backward(20)
    right(85)
    forward(18)
    circle(10)
    end_fill()

# %%
def nose():
    myPosition(0,306)
    right(60)
    circle(3,140)
    myPosition(-12,304)
    right(-8)
    circle(3,-140)

# %%
def mouth():
    myPosition(1,288)
    fillcolor('#FFFFFF')
    begin_fill()
    right(90)
    circle(30,25)
    right(120)
    forward(10)
    right(180)
    circle(3,-180)
    right(130)
    forward(10)
    end_fill()

# %%
def hair():
    myPosition(-38,350)
    fillcolor('#FFFF00')
    begin_fill() 
    right(240)
    circle(100,-60)
    circle(10,-140)
    myPosition(-20,352)
    end_fill()

# %%
def hairo():
  myPosition(-20,352)
  fillcolor('#FFFF00')
  begin_fill()
  right(165)
  circle(100,-70)
  circle(10,-140)
  myPosition(0,352)
  end_fill()

# %%
def hairt():
  myPosition(0,352)
  fillcolor('#FFFF00')
  begin_fill()
  right(155)
  circle(100,-50)
  circle(10,-140)
  myPosition(10,354)
  end_fill()

# %%
def hairth():
  myPosition(10,354)
  fillcolor('#FFFF00')
  begin_fill()
  right(125)
  circle(100,40)
  circle(10,100)
  myPosition(0,352)
  end_fill()

# %%
def hairf():
  myPosition(20,354)
  fillcolor('#FFFF00')
  begin_fill()
  right(55)
  circle(100,30)
  circle(10,100)
  myPosition(10,354)
  end_fill()

# %%
def hairtrl():
    myPosition(-38,350)
    fillcolor('#FFFF00')
    begin_fill()
    forward(7)
    right(-105)
    forward(22)
    end_fill()

# %%
def hairtrr():
    myPosition(23,353)
    fillcolor('#FFFF00')
    begin_fill()
    right(110)
    forward(-7)
    right(-65)
    forward(22)
    end_fill()

# %%
ankur()
legbleow()
legbleowr()
shoesr()
shoels()
shirt()
handl()
handr()
neck()
face()
earsl()
earsr()
glass()
nose()
mouth()
hair()
hairo()
hairt()
hairf()
hairth()
hairtrl()
hairtrr()
ht()
done()
